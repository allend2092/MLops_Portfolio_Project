# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_parquet("../data/processed/combined_events.parquet")
print(df["source"].value_counts())
# Out:
# source
# systemd    457
# docker      95
# gpu         10
# Name: count, dtype: int64
